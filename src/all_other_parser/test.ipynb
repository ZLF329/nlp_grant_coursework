# %%
import json, sys, pathlib

# 把 src 目录加入路径，确保能 import all_other_parser
sys.path.insert(0, str(pathlib.Path("..").resolve()))

from all_other_parser import convert_to_unified_format

# 读取 478.json
input_path = pathlib.Path("../../test_results/IC00009_after.json")
with open(input_path, encoding="utf-8") as f:
    sections_json = json.load(f)

# 转换
result = convert_to_unified_format(sections_json)

# 打印结果
print(json.dumps(result, ensure_ascii=False, indent=2))
# Out:
# {
#   "APPLICATION DETAILS": {
# ...

# %%
# 读取 478.json
input_path = pathlib.Path("../../test_results/478.json")
with open(input_path, encoding="utf-8") as f:
    sections_json = json.load(f)

# 转换
result = convert_to_unified_format(sections_json)

# 打印结果
print(json.dumps(result, ensure_ascii=False, indent=2))
# Out:
# {
#   "APPLICATION DETAILS": {
#     "Scientific Abstract": "Knee osteoarthritis (KOA) is a growing health challenge, affecting 367 million people worldwide and placing a\nsignificant strain on healthcare systems. In the UK, the healthcare cost exceeds £2.53 billion annually, a figure\nexpected to rise as the population ages. One major issue in KOA diagnosis lies in the referral process between GPs\nand radiologists. The way referrals are written often influences radiology reports, reinforcing diagnostic bias. This\nfeedback loop means patients suspected of KOA are more likely to receive a confirmed diagnosis, even when\nuncertainty remains. At the same time, GPs rely heavily on radiology reports to support their initial assessments,\nhttps://funding-service.ukri.org/applications/APP75384 1/49"
#   }
# }
